# %% [markdown]
# # Single-Cell Report: Clustering

# %%
# Import packages
import scanpy as sc

# %% [markdown]
# #### Plotting settings and functions

# %%
# plot settings
sc.set_figure_params(dpi=150, fontsize=10, dpi_save=600)

# %% [markdown]
# #### Read Data

# %%
adata = sc.read_h5ad(filename=FILE)

# %%
# select features to show in the plots below
features = ['sample_id','batch','louvain'] #,'n_counts','percent_mito']
# keep only features that are present in the data:
features = [ x for x in features if x in adata.obs.columns ]

# %% [markdown]
# ---
# ## Clustering

# %%
print(f"Louvain resolution: {adata.uns['louvain']['params']['resolution']}")
if('X_pca' in adata.obsm):
    sc.pl.pca(adata, color=features, palette=sc.pl.palettes.default_64, wspace=0.5)
if('X_tsne' in adata.obsm):
    sc.pl.tsne(adata, color=features, palette=sc.pl.palettes.default_64, wspace=0.5)
if('X_umap' in adata.obsm):
    sc.pl.umap(adata, color=features, palette=sc.pl.palettes.default_64, wspace=0.5)
